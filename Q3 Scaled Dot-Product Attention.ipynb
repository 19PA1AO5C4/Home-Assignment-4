# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1AO5C4/Home-Assignment-4/blob/main/Q3%20Scaled%20Dot-Product%20Attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

def softmax(x):
    e_x = np.exp(x - np.max(x, axis=-1, keepdims=True))  # Stability improvement
    return e_x / np.sum(e_x, axis=-1, keepdims=True)

def scaled_dot_product_attention(Q, K, V):
    # Step 1: Compute dot product of Q and Kᵀ
    scores = np.dot(Q, K.T)

    # Step 2: Scale by √d (d = dimension of key vectors)
    d = K.shape[1]
    scaled_scores = scores / np.sqrt(d)

    # Step 3: Apply softmax to get attention weights
    attention_weights = softmax(scaled_scores)

    # Step 4: Multiply attention weights by V
    output = np.dot(attention_weights, V)

    # Display results
    print("Attention Weights:\n", attention_weights)
    print("Final Output:\n", output)

# Test Inputs
Q = np.array([[1, 0, 1, 0], [0, 1, 0, 1]])
K = np.array([[1, 0, 1, 0], [0, 1, 0, 1]])
V = np.array([[1, 2, 3, 4], [5, 6, 7, 8]])

# Run the attention mechanism
scaled_dot_product_attention(Q, K, V)
# Out:
# Attention Weights:
#  [[0.73105858 0.26894142]
#  [0.26894142 0.73105858]]
# Final Output:
#  [[2.07576569 3.07576569 4.07576569 5.07576569]
#  [3.92423431 4.92423431 5.92423431 6.92423431]]
